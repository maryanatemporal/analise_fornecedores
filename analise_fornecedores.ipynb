# %%
df_analise = pd.read_csv("analise_fornecedores.csv", encoding='latin1', sep=";", low_memory=False)
display(df_analise)

display(df_analise.info())
# Out:
#     id_pedido data_pedido               fornecedor  produto  preco_kg  \
# 0           1  05/01/2025          Frigorífico Sul  Picanha      82.0
# 1           2  07/01/2025           Carnes Premium   Frango      20.0
# 2           3  09/01/2025           Proteína Nobre  Costela      47.0
# 3           4  10/01/2025          Frigorifico Sul  Picanha      80.0
# 4           5  12/01/2025  Distribuidora Boi Forte   Frango      17.0
# 5           6  14/01/2025           Carnes Premium  Picanha      95.0
# 6           7  16/01/2025           Proteína Nobre   Frango      19.0
# 7           8  18/01/2025          Frigorífico Sul  Costela      45.0
# 8           9  20/01/2025           Carnes Premium  Costela      52.0
# 9          10  22/01/2025           Proteina Nobre  Picanha      88.0
# 10         11  24/01/2025  Distribuidora Boi Forte  Picanha      79.0
# 11         12  25/01/2025           Carnes Premium   Frango       NaN
# 12         13  26/01/2025          Frigorífico Sul   Frango      18.0
# 13         14  27/01/2025           Proteína Nobre  Costela      47.0
# 14         15  29/01/2025           Carnes Premium  Picanha      96.0
# 15         16  01/02/2025  Distribuidora Boi Forte   Frango      17.0
# 16         17  02/02/2025          Frigorífico Sul  Picanha     -80.0
# 17         18  03/02/2025           Carnes Premium  Costela      51.0
# 18         19  05/02/2025           Proteína Nobre   Frango      19.0
# 19         20  07/02/2025          Frigorífico Sul  Costela      44.0
# 20         21  08/02/2025           Carnes Premium  Picanha      94.0
# 21         22  09/02/2025  Distribuidora Boi Forte  Picanha      78.0
# 22         23  10/02/2025           Proteína Nobre  Picanha      88.0
# 23         24  11/02/2025           Carnes Premium   Frango      21.0
# 24         25  12/02/2025          Frigorífico Sul   Frango      18.0
# 25         26  14/02/2025           Proteína Nobre  Costela      46.0
# 26         27  15/02/2025           Carnes Premium  Costela      53.0
# 27         28  16/02/2025  Distribuidora Boi Forte   Frango      17.0
# 28         29  18/02/2025          Frigorífico Sul  Picanha      83.0
# 29         30  19/02/2025           Carnes Premium  Picanha     300.0
# 30         31  20/02/2025           Proteína Nobre   Frango      19.0
# 31         32  22/02/2025          Frigorífico Sul  Costela      45.0
# 32         33  23/02/2025           Carnes Premium   Frango      20.0
# 33         34  24/02/2025           Proteína Nobre  Picanha      89.0
# 34         35  25/02/2025  Distribuidora Boi Forte  Costela      40.0
# 35         36  27/02/2025          Frigorífico Sul   Frango      18.0
# 36         37  28/02/2025           Carnes Premium  Picanha      95.0
# 37         38  01/03/2025           Proteína Nobre  Costela      47.0
# 38         39  02/03/2025  Distribuidora Boi Forte  Picanha      79.0
# 39         40  03/03/2025          Frigorífico Sul  Costela      45.0
#
#     quantidade_kg  qualidade  aceitacao_socios  tempo_entrega_dias  \
# 0              25          8                 9                 2.0
# 1              40          8                 8                 3.0
# 2              35          8                 7                 2.0
# 3              20          7                 8                 2.0
# 4              50          6                 7                 4.0
# 5              15          9                 9                 3.0
# 6              60          7                 7                 2.0
# 7              30          8                 8                 3.0
# 8              28          9                 9                 3.0
# 9              18          8                 8                 2.0
# 10             20          7                 7                 4.0
# 11             35          8                 8                 3.0
# 12             45          7                 8                 2.0
# 13             33          8                 7                 NaN
# 14             12          9                 9                 3.0
# 15             48          6                 6                 4.0
# 16             22          8                 8                 2.0
# 17             27          9                 9                 3.0
# 18             55          7                 7                 2.0
# 19             32          8                 8                 3.0
# 20             14          9                 9                 3.0
# 21             19          7                 7                 4.0
# 22             16          8                 8                 2.0
# 23             38          8                 8                 3.0
# 24             42          7                 8                 2.0
# 25             34          8                 7                 2.0
# 26             26          9                 9                 3.0
# 27             52          6                 6                 4.0
# 28             21          8                 9                 2.0
# 29             10          9                 9                 3.0
# 30             58          7                 7                 2.0
# 31             29          8                 8                 3.0
# 32             41          8                 8                 3.0
# 33             17          8                 8                 2.0
# 34             30          6                 6                 4.0
# 35             44          7                 8                 2.0
# 36             13          9                 9                 3.0
# 37             31          8                 7                 2.0
# 38             18          7                 7                 4.0
# 39             30          8                 8                 3.0
#
#     avaliacao_chef          observacao
# 0                9      entrega rápida
# 1                8                 NaN
# 2                8                 NaN
# 3                8        erro no nome
# 4                6   atraso na entrega
# 5                9                 NaN
# 6                7                 NaN
# 7                8                 NaN
# 8                9                 NaN
# 9                8  nome inconsistente
# 10               7                 NaN
# 11               8      preço faltando
# 12               7                 NaN
# 13               8      tempo faltando
# 14               9                 NaN
# 15               6                 NaN
# 16               8      preço negativo
# 17               9                 NaN
# 18               7                 NaN
# 19               8                 NaN
# 20               9                 NaN
# 21               7                 NaN
# 22               8                 NaN
# 23               8                 NaN
# 24               7                 NaN
# 25               8                 NaN
# 26               9                 NaN
# 27               6                 NaN
# 28               9                 NaN
# 29               9       preço absurdo
# 30               7                 NaN
# 31               8                 NaN
# 32               8                 NaN
# 33               8                 NaN
# 34               6                 NaN
# 35               7                 NaN
# 36               9                 NaN
# 37               8                 NaN
# 38               7                 NaN
# 39               8                 NaN
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id_pedido           40 non-null     int64
#  1   data_pedido         40 non-null     object
#  2   fornecedor          40 non-null     object
#  3   produto             40 non-null     object
#  4   preco_kg            39 non-null     float64
#  5   quantidade_kg       40 non-null     int64
#  6   qualidade           40 non-null     int64
#  7   aceitacao_socios    40 non-null     int64
#  8   tempo_entrega_dias  39 non-null     float64
#  9   avaliacao_chef      40 non-null     int64
#  10  observacao          8 non-null      object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 3.6+ KB
# None

# %% [markdown]
# 1. Análise de Fornecedores
#
# Este projeto tem como objetivo analisar dados de fornecedores, realizando limpeza e extraindo insights para tomada de decisão.

# %% [markdown]
# 2. Importação de bibliotecas

# %%
import pandas as pd
import numpy as np
import unicodedata

# %% [markdown]
# 3. Leitura dos dados

# %%
df_analise = pd.read_csv("analise_fornecedores.csv", encoding='latin1', sep=";", low_memory=False)
display(df_analise)

display(df_analise.info())
# Out:
#     id_pedido data_pedido               fornecedor  produto  preco_kg  \
# 0           1  05/01/2025          Frigorífico Sul  Picanha      82.0
# 1           2  07/01/2025           Carnes Premium   Frango      20.0
# 2           3  09/01/2025           Proteína Nobre  Costela      47.0
# 3           4  10/01/2025          Frigorifico Sul  Picanha      80.0
# 4           5  12/01/2025  Distribuidora Boi Forte   Frango      17.0
# 5           6  14/01/2025           Carnes Premium  Picanha      95.0
# 6           7  16/01/2025           Proteína Nobre   Frango      19.0
# 7           8  18/01/2025          Frigorífico Sul  Costela      45.0
# 8           9  20/01/2025           Carnes Premium  Costela      52.0
# 9          10  22/01/2025           Proteina Nobre  Picanha      88.0
# 10         11  24/01/2025  Distribuidora Boi Forte  Picanha      79.0
# 11         12  25/01/2025           Carnes Premium   Frango       NaN
# 12         13  26/01/2025          Frigorífico Sul   Frango      18.0
# 13         14  27/01/2025           Proteína Nobre  Costela      47.0
# 14         15  29/01/2025           Carnes Premium  Picanha      96.0
# 15         16  01/02/2025  Distribuidora Boi Forte   Frango      17.0
# 16         17  02/02/2025          Frigorífico Sul  Picanha     -80.0
# 17         18  03/02/2025           Carnes Premium  Costela      51.0
# 18         19  05/02/2025           Proteína Nobre   Frango      19.0
# 19         20  07/02/2025          Frigorífico Sul  Costela      44.0
# 20         21  08/02/2025           Carnes Premium  Picanha      94.0
# 21         22  09/02/2025  Distribuidora Boi Forte  Picanha      78.0
# 22         23  10/02/2025           Proteína Nobre  Picanha      88.0
# 23         24  11/02/2025           Carnes Premium   Frango      21.0
# 24         25  12/02/2025          Frigorífico Sul   Frango      18.0
# 25         26  14/02/2025           Proteína Nobre  Costela      46.0
# 26         27  15/02/2025           Carnes Premium  Costela      53.0
# 27         28  16/02/2025  Distribuidora Boi Forte   Frango      17.0
# 28         29  18/02/2025          Frigorífico Sul  Picanha      83.0
# 29         30  19/02/2025           Carnes Premium  Picanha     300.0
# 30         31  20/02/2025           Proteína Nobre   Frango      19.0
# 31         32  22/02/2025          Frigorífico Sul  Costela      45.0
# 32         33  23/02/2025           Carnes Premium   Frango      20.0
# 33         34  24/02/2025           Proteína Nobre  Picanha      89.0
# 34         35  25/02/2025  Distribuidora Boi Forte  Costela      40.0
# 35         36  27/02/2025          Frigorífico Sul   Frango      18.0
# 36         37  28/02/2025           Carnes Premium  Picanha      95.0
# 37         38  01/03/2025           Proteína Nobre  Costela      47.0
# 38         39  02/03/2025  Distribuidora Boi Forte  Picanha      79.0
# 39         40  03/03/2025          Frigorífico Sul  Costela      45.0
#
#     quantidade_kg  qualidade  aceitacao_socios  tempo_entrega_dias  \
# 0              25          8                 9                 2.0
# 1              40          8                 8                 3.0
# 2              35          8                 7                 2.0
# 3              20          7                 8                 2.0
# 4              50          6                 7                 4.0
# 5              15          9                 9                 3.0
# 6              60          7                 7                 2.0
# 7              30          8                 8                 3.0
# 8              28          9                 9                 3.0
# 9              18          8                 8                 2.0
# 10             20          7                 7                 4.0
# 11             35          8                 8                 3.0
# 12             45          7                 8                 2.0
# 13             33          8                 7                 NaN
# 14             12          9                 9                 3.0
# 15             48          6                 6                 4.0
# 16             22          8                 8                 2.0
# 17             27          9                 9                 3.0
# 18             55          7                 7                 2.0
# 19             32          8                 8                 3.0
# 20             14          9                 9                 3.0
# 21             19          7                 7                 4.0
# 22             16          8                 8                 2.0
# 23             38          8                 8                 3.0
# 24             42          7                 8                 2.0
# 25             34          8                 7                 2.0
# 26             26          9                 9                 3.0
# 27             52          6                 6                 4.0
# 28             21          8                 9                 2.0
# 29             10          9                 9                 3.0
# 30             58          7                 7                 2.0
# 31             29          8                 8                 3.0
# 32             41          8                 8                 3.0
# 33             17          8                 8                 2.0
# 34             30          6                 6                 4.0
# 35             44          7                 8                 2.0
# 36             13          9                 9                 3.0
# 37             31          8                 7                 2.0
# 38             18          7                 7                 4.0
# 39             30          8                 8                 3.0
#
#     avaliacao_chef          observacao
# 0                9      entrega rápida
# 1                8                 NaN
# 2                8                 NaN
# 3                8        erro no nome
# 4                6   atraso na entrega
# 5                9                 NaN
# 6                7                 NaN
# 7                8                 NaN
# 8                9                 NaN
# 9                8  nome inconsistente
# 10               7                 NaN
# 11               8      preço faltando
# 12               7                 NaN
# 13               8      tempo faltando
# 14               9                 NaN
# 15               6                 NaN
# 16               8      preço negativo
# 17               9                 NaN
# 18               7                 NaN
# 19               8                 NaN
# 20               9                 NaN
# 21               7                 NaN
# 22               8                 NaN
# 23               8                 NaN
# 24               7                 NaN
# 25               8                 NaN
# 26               9                 NaN
# 27               6                 NaN
# 28               9                 NaN
# 29               9       preço absurdo
# 30               7                 NaN
# 31               8                 NaN
# 32               8                 NaN
# 33               8                 NaN
# 34               6                 NaN
# 35               7                 NaN
# 36               9                 NaN
# 37               8                 NaN
# 38               7                 NaN
# 39               8                 NaN
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id_pedido           40 non-null     int64
#  1   data_pedido         40 non-null     object
#  2   fornecedor          40 non-null     object
#  3   produto             40 non-null     object
#  4   preco_kg            39 non-null     float64
#  5   quantidade_kg       40 non-null     int64
#  6   qualidade           40 non-null     int64
#  7   aceitacao_socios    40 non-null     int64
#  8   tempo_entrega_dias  39 non-null     float64
#  9   avaliacao_chef      40 non-null     int64
#  10  observacao          8 non-null      object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 3.6+ KB
# None

# %% [markdown]
# #Problemas identificados
#
# - Datas em formato incorreto
# - Valores nulos e inconsistentes
# - Falta de padronização nos fornecedores

# %% [markdown]
# 4. Limpeza

# %%
#Convertendo datas

df_analise["data_pedido"] = pd.to_datetime(df_analise["data_pedido"], format="%d/%m/%Y")
df_analise = df_analise.sort_values(by="data_pedido", ascending=True)

#Padronização fornecedores

df_analise["fornecedor"] = df_analise["fornecedor"].str.strip().str.title()

import unicodedata

def remover_acentos(texto):
    return unicodedata.normalize("NFKD", texto).encode("ASCII", "ignore").decode("ASCII")

df_analise["fornecedor"] = df_analise["fornecedor"].apply(remover_acentos)

df_analise["fornecedor"].value_counts()

#Tratando valores nuloes

df_analise[(df_analise["fornecedor"] == "Carnes premium") & (df_analise["produto"] == "Frango")]
# Out:
# Empty DataFrame
# Columns: [id_pedido, data_pedido, fornecedor, produto, preco_kg, quantidade_kg, qualidade, aceitacao_socios, tempo_entrega_dias, avaliacao_chef, observacao]
# Index: []

# %%
df_analise[(df_analise["fornecedor"] == "Carnes Premium") & (df_analise["produto"] == "Frango")]["preco_kg"].mean()
# Out:
# np.float64(20.333333333333332)

# %%
df_analise.loc[
    (df_analise["fornecedor"] == "Carnes premium") &
    (df_analise["produto"] == "Frango") &
    (df_analise["preco_kg"].isna()),
    "preco_kg"
] = 20.33
display(df_analise["preco_kg"].unique())
# Out:
# array([ 82.,  20.,  47.,  80.,  17.,  95.,  19.,  45.,  52.,  88.,  79.,
#         nan,  18.,  96., -80.,  51.,  44.,  94.,  78.,  21.,  46.,  53.,
#         83., 300.,  89.,  40.])

# %% [markdown]
# Tratando valores negativos

# %%
df_analise.loc[df_analise["preco_kg"] < 0, "preco_kg"] = None
display(df_analise["preco_kg"].unique())
# Out:
# array([ 82.,  20.,  47.,  80.,  17.,  95.,  19.,  45.,  52.,  88.,  79.,
#         nan,  18.,  96.,  51.,  44.,  94.,  78.,  21.,  46.,  53.,  83.,
#        300.,  89.,  40.])

# %%
display(df_analise[["id_pedido", "fornecedor",	"produto",	"preco_kg",	"quantidade_kg"]])
# Out:
#     id_pedido               fornecedor  produto  preco_kg  quantidade_kg
# 0           1          Frigorifico Sul  Picanha      82.0             25
# 1           2           Carnes Premium   Frango      20.0             40
# 2           3           Proteina Nobre  Costela      47.0             35
# 3           4          Frigorifico Sul  Picanha      80.0             20
# 4           5  Distribuidora Boi Forte   Frango      17.0             50
# 5           6           Carnes Premium  Picanha      95.0             15
# 6           7           Proteina Nobre   Frango      19.0             60
# 7           8          Frigorifico Sul  Costela      45.0             30
# 8           9           Carnes Premium  Costela      52.0             28
# 9          10           Proteina Nobre  Picanha      88.0             18
# 10         11  Distribuidora Boi Forte  Picanha      79.0             20
# 11         12           Carnes Premium   Frango       NaN             35
# 12         13          Frigorifico Sul   Frango      18.0             45
# 13         14           Proteina Nobre  Costela      47.0             33
# 14         15           Carnes Premium  Picanha      96.0             12
# 15         16  Distribuidora Boi Forte   Frango      17.0             48
# 16         17          Frigorifico Sul  Picanha       NaN             22
# 17         18           Carnes Premium  Costela      51.0             27
# 18         19           Proteina Nobre   Frango      19.0             55
# 19         20          Frigorifico Sul  Costela      44.0             32
# 20         21           Carnes Premium  Picanha      94.0             14
# 21         22  Distribuidora Boi Forte  Picanha      78.0             19
# 22         23           Proteina Nobre  Picanha      88.0             16
# 23         24           Carnes Premium   Frango      21.0             38
# 24         25          Frigorifico Sul   Frango      18.0             42
# 25         26           Proteina Nobre  Costela      46.0             34
# 26         27           Carnes Premium  Costela      53.0             26
# 27         28  Distribuidora Boi Forte   Frango      17.0             52
# 28         29          Frigorifico Sul  Picanha      83.0             21
# 29         30           Carnes Premium  Picanha     300.0             10
# 30         31           Proteina Nobre   Frango      19.0             58
# 31         32          Frigorifico Sul  Costela      45.0             29
# 32         33           Carnes Premium   Frango      20.0             41
# 33         34           Proteina Nobre  Picanha      89.0             17
# 34         35  Distribuidora Boi Forte  Costela      40.0             30
# 35         36          Frigorifico Sul   Frango      18.0             44
# 36         37           Carnes Premium  Picanha      95.0             13
# 37         38           Proteina Nobre  Costela      47.0             31
# 38         39  Distribuidora Boi Forte  Picanha      79.0             18
# 39         40          Frigorifico Sul  Costela      45.0             30

# %%
df_id_pedido_17= df_analise[df_analise["id_pedido"]==17]
display(df_id_pedido_17)
# Out:
#     id_pedido data_pedido       fornecedor  produto  preco_kg  quantidade_kg  \
# 16         17  2025-02-02  Frigorifico Sul  Picanha       NaN             22
#
#     qualidade  aceitacao_socios  tempo_entrega_dias  avaliacao_chef  \
# 16          8                 8                 2.0               8
#
#         observacao
# 16  preço negativo

# %%
df_analise[(df_analise["fornecedor"] == "Frigorifico Sul") & (df_analise["produto"] == "Picanha")]["preco_kg"].mean()
# Out:
# np.float64(81.66666666666667)

# %%
df_analise.loc[
    (df_analise["fornecedor"] == "Frigorifico Sul") &
    (df_analise["produto"] == "Picanha") &
    (df_analise["preco_kg"].isna()),
    "preco_kg"
] = 81.66
display(df_analise["preco_kg"].unique())
# Out:
# array([ 82.  ,  20.  ,  47.  ,  80.  ,  17.  ,  95.  ,  19.  ,  45.  ,
#         52.  ,  88.  ,  79.  ,    nan,  18.  ,  96.  ,  81.66,  51.  ,
#         44.  ,  94.  ,  78.  ,  21.  ,  46.  ,  53.  ,  83.  , 300.  ,
#         89.  ,  40.  ])

# %%
preco_medio = df_analise.groupby("fornecedor")["preco_kg"].mean().round(2)
avaliacao = df_analise.groupby("fornecedor")["avaliacao_chef"].mean().round(2)
tempo = df_analise.groupby("fornecedor")["tempo_entrega_dias"].mean().round(2)

resultado = pd.DataFrame({
    "preco_medio": preco_medio,
    "avaliacao": avaliacao,
    "tempo_entrega_dias": tempo
})

resultado
# Out:
#                          preco_medio  avaliacao  tempo_entrega_dias
# fornecedor
# Carnes Premium                 81.55       8.67                3.00
# Distribuidora Boi Forte        46.71       6.43                4.00
# Frigorifico Sul                50.88       7.91                2.36
# Proteina Nobre                 50.90       7.70                2.00

# %% [markdown]
# ## Insights
#
# - A **Carnes Premium** apresenta o maior preço médio (R$ 81,55/kg), porém também possui a melhor avaliação (8,67), indicando um posicionamento premium com foco em qualidade.
#
# - A **Distribuidora Boi Forte** possui o menor preço médio (R$ 46,71/kg), mas também a menor avaliação (6,43) e o maior tempo de entrega (4 dias), sugerindo menor qualidade e eficiência.
#
# - O **Frigorífico Sul** apresenta bom equilíbrio entre preço (R$ 50,88/kg), avaliação (7,91) e tempo de entrega (2 dias), sendo uma opção de melhor custo-benefício.
#
# - A **Proteína Nobre** possui o menor tempo médio de entrega (2 dias), com preço e avaliação intermediários, sendo uma boa opção para rapidez.
#
# - De forma geral, observa-se uma relação entre preço e qualidade: fornecedores mais caros tendem a apresentar melhores avaliações.
#
# - Conclusão: a escolha do fornecedor ideal depende do objetivo do negócio: redução de custos, qualidade do produto ou rapidez na entrega.
